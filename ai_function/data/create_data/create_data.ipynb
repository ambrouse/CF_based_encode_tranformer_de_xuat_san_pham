# %%
import numpy as np
import random
import string

num_samples = 500_000

def get_brand_by_product(product_name):
    brand_mapping = {
        "Áo sơ mi nam": "Brand A", "Áo sơ mi nữ": "Brand A","Quần jean nam": "Brand B", "Quần jean nữ": "Brand B",
        "Áo thun nam": "Brand C", "Áo thun nữ": "Brand C","Áo khoác nam": "Brand D", "Áo khoác nữ": "Brand D",
        "Giày thể thao nam": "Brand E", "Giày thể thao nữ": "Brand E","Giày cao gót": "Brand F", "Túi xách nữ": "Brand G",
        "Balo nam": "Brand H", "Balo nữ": "Brand H","Mắt kính thời trang": "Brand I", "Đồng hồ nam": "Brand J",
        "Đồng hồ nữ": "Brand J", "Quần jogger nam": "Brand K","Quần jogger nữ": "Brand K", "Đầm dạ hội": "Brand L",
        "Váy công sở": "Brand M", "Quần legging nữ": "Brand N","Áo hoodie nam": "Brand O", "Áo hoodie nữ": "Brand O",
        "Áo gió nam": "Brand P", "Áo gió nữ": "Brand P","Tất nam": "Brand Q", "Tất nữ": "Brand Q",
        "Thắt lưng nam": "Brand R", "Thắt lưng nữ": "Brand R","Khăn choàng cổ": "Brand S", "Găng tay da": "Brand T",
        "Quần short nam": "Brand U", "Quần short nữ": "Brand U","Bộ đồ ngủ nữ": "Brand V", "Bộ pijama nam": "Brand W",
        "Bộ pijama nữ": "Brand W", "Bộ vest nam": "Brand X","Bộ vest nữ": "Brand X", "Váy maxi": "Brand Y",
        "Giày lười nam": "Brand Z", "Dép sandal nữ": "Brand AA","Áo dài truyền thống": "Brand AB", "Áo dài cách tân": "Brand AB",
        "Quần yếm nữ": "Brand AC", "Khăn lụa nữ": "Brand AD","Mũ lưỡi trai nam": "Brand AE", "Mũ rộng vành nữ": "Brand AF",
        "Găng tay len": "Brand AG", "Áo len nam": "Brand AH","Áo len nữ": "Brand AH"
    }
    return brand_mapping.get(product_name, "Brand Unknown")

def get_category_by_product(product_name):
    category_map = {
        "Áo sơ mi nam": "Áo sơ mi","Áo sơ mi nữ": "Áo sơ mi","Quần jean nam": "Quần jean",
        "Quần jean nữ": "Quần jean","Áo thun nam": "Áo thun","Áo thun nữ": "Áo thun",
        "Áo khoác nam": "Áo khoác","Áo khoác nữ": "Áo khoác","Giày thể thao nam": "Giày thể thao","Giày thể thao nữ": "Giày thể thao",
        "Giày cao gót": "Giày nữ","Túi xách nữ": "Túi xách","Balo nam": "Balo","Balo nữ": "Balo",
        "Mắt kính thời trang": "Phụ kiện","Đồng hồ nam": "Đồng hồ","Đồng hồ nữ": "Đồng hồ",
        "Quần jogger nam": "Quần jogger","Quần jogger nữ": "Quần jogger","Đầm dạ hội": "Đầm váy",
        "Váy công sở": "Đầm váy","Quần legging nữ": "Quần legging","Áo hoodie nam": "Áo hoodie",
        "Áo hoodie nữ": "Áo hoodie","Áo gió nam": "Áo gió","Áo gió nữ": "Áo gió","Tất nam": "Tất",
        "Tất nữ": "Tất","Thắt lưng nam": "Thắt lưng","Thắt lưng nữ": "Thắt lưng","Khăn choàng cổ": "Phụ kiện",
        "Găng tay da": "Găng tay","Quần short nam": "Quần short","Quần short nữ": "Quần short","Bộ đồ ngủ nữ": "Bộ đồ ngủ",
        "Bộ pijama nam": "Bộ pijama","Bộ pijama nữ": "Bộ pijama","Bộ vest nam": "Bộ vest","Bộ vest nữ": "Bộ vest",
        "Váy maxi": "Đầm váy","Giày lười nam": "Giày nam","Dép sandal nữ": "Dép nữ","Áo dài truyền thống": "Áo dài",
        "Áo dài cách tân": "Áo dài","Quần yếm nữ": "Quần yếm","Khăn lụa nữ": "Phụ kiện","Mũ lưỡi trai nam": "Mũ",
        "Mũ rộng vành nữ": "Mũ","Găng tay len": "Găng tay","Áo len nam": "Áo len","Áo len nữ": "Áo len"
    }
    
    return category_map.get(product_name, "Khác")
    
def get_fashion_style_by_product(product_name):
    fashion_style_mapping = {
        "Áo sơ mi nam": "Công sở", "Áo sơ mi nữ": "Công sở","Quần jean nam": "Casual", "Quần jean nữ": "Casual",
        "Áo thun nam": "Streetwear", "Áo thun nữ": "Streetwear","Áo khoác nam": "Streetwear", "Áo khoác nữ": "Streetwear",
        "Giày thể thao nam": "Thể thao", "Giày thể thao nữ": "Thể thao","Giày cao gót": "Thanh lịch", "Túi xách nữ": "Thời trang",
        "Balo nam": "Thể thao", "Balo nữ": "Thể thao","Mắt kính thời trang": "Phụ kiện", "Đồng hồ nam": "Phụ kiện",
        "Đồng hồ nữ": "Phụ kiện", "Quần jogger nam": "Thể thao","Quần jogger nữ": "Thể thao", "Đầm dạ hội": "Thanh lịch",
        "Váy công sở": "Công sở", "Quần legging nữ": "Thể thao","Áo hoodie nam": "Streetwear", "Áo hoodie nữ": "Streetwear",
        "Áo gió nam": "Thể thao", "Áo gió nữ": "Thể thao","Tất nam": "Phụ kiện", "Tất nữ": "Phụ kiện",
        "Thắt lưng nam": "Phụ kiện", "Thắt lưng nữ": "Phụ kiện","Khăn choàng cổ": "Phụ kiện", "Găng tay da": "Cá tính",
        "Quần short nam": "Casual", "Quần short nữ": "Casual","Bộ đồ ngủ nữ": "Đồ ngủ", "Bộ pijama nam": "Đồ ngủ",
        "Bộ pijama nữ": "Đồ ngủ", "Bộ vest nam": "Công sở","Bộ vest nữ": "Công sở", "Váy maxi": "Bohemian",
        "Giày lười nam": "Lịch lãm", "Dép sandal nữ": "Casual","Áo dài truyền thống": "Truyền thống", "Áo dài cách tân": "Truyền thống",
        "Quần yếm nữ": "Vintage", "Khăn lụa nữ": "Thanh lịch","Mũ lưỡi trai nam": "Streetwear", "Mũ rộng vành nữ": "Thời trang",
        "Găng tay len": "Phụ kiện", "Áo len nam": "Casual","Áo len nữ": "Casual"
    }
    return fashion_style_mapping.get(product_name, "Không xác định")

def get_fashion_size_by_product(product_name):
    size_mapping = {
    "Áo sơ mi nam": "L", "Áo sơ mi nữ": "M","Quần jean nam": "32", "Quần jean nữ": "28",
    "Áo thun nam": "L", "Áo thun nữ": "M","Áo khoác nam": "XL", "Áo khoác nữ": "L",
    "Giày thể thao nam": "42", "Giày thể thao nữ": "38","Giày cao gót": "37", "Túi xách nữ": "One size",
    "Balo nam": "One size", "Balo nữ": "One size","Mắt kính thời trang": "One size", "Đồng hồ nam": "One size",
    "Đồng hồ nữ": "One size", "Quần jogger nam": "32","Quần jogger nữ": "28", "Đầm dạ hội": "M",
    "Váy công sở": "M", "Quần legging nữ": "M","Áo hoodie nam": "XL", "Áo hoodie nữ": "L",
    "Áo gió nam": "XL", "Áo gió nữ": "L","Tất nam": "One size", "Tất nữ": "One size",
    "Thắt lưng nam": "One size", "Thắt lưng nữ": "One size","Khăn choàng cổ": "One size", "Găng tay da": "One size",
    "Quần short nam": "32", "Quần short nữ": "28","Bộ đồ ngủ nữ": "M", "Bộ pijama nam": "L",
    "Bộ pijama nữ": "M", "Bộ vest nam": "L","Bộ vest nữ": "M", "Váy maxi": "M",
    "Giày lười nam": "42", "Dép sandal nữ": "38","Áo dài truyền thống": "L", "Áo dài cách tân": "M",
    "Quần yếm nữ": "M", "Khăn lụa nữ": "One size","Mũ lưỡi trai nam": "One size", "Mũ rộng vành nữ": "One size",
    "Găng tay len": "One size", "Áo len nam": "L","Áo len nữ": "M"
}
    return size_mapping.get(product_name, "Không xác định")

def generate_name():
    first_names = ["Nguyễn", "Trần", "Lê", "Phạm", "Hoàng", "Huỳnh", "Phan", "Vũ", "Võ", "Đặng",
    "Bùi", "Đỗ", "Hồ", "Ngô", "Dương", "Lý", "Tô", "Tôn", "Văn", "Lưu",
    "Trịnh", "Đinh", "Mai", "Hà", "Cao", "Lâm", "Thái", "Tạ", "Từ", "Chu",
    "Đoàn", "Thạch", "Quách", "Tống", "Hứa", "La", "Triệu", "Kiều", "Tiêu", "Hồng",
    "Nhâm", "Bành", "Tôn Nữ", "Vương", "Khương", "Tăng", "Ôn", "Trương", "Thiều", "Diệp",
    "Tôn Thất", "Văn Công", "Đinh Công", "Lý Nhật", "Nguyễn Hữu", "Hoàng Văn", "Lâm Văn", "Phan Nhật", "Tạ Đình", "Đàm",
    "Lạc", "Mạc", "Kha", "Đào", "Phùng", "Nguyễn Văn", "Trần Văn", "Lê Văn", "Hoàng Đức", "Vũ Văn",
    "Nguyễn Duy", "Nguyễn Đình", "Trần Đình", "Lê Đình", "Phạm Đình", "Bùi Đình", "Ngô Văn", "Đỗ Đức", "Từ Minh", "Hà Văn",
    "Trịnh Công", "Dương Minh", "Lương Văn", "Đinh Ngọc", "Võ Quốc", "Phan Gia", "Nguyễn Tấn", "Trần Duy", "Đặng Minh", "Đoàn Văn",
    "Thân", "Châu", "Cù", "Nghiêm", "Tào", "Địch", "Mẫn", "Bắc", "Thượng", "Uông"]
    last_names = [ "Bảo", "An", "Duy", "Hưng", "Minh", "Nam", "Phong", "Quân", "Tùng", "Vinh",
    "Đạt", "Khoa", "Hải", "Hiếu", "Khánh", "Long", "Lâm", "Sơn", "Thắng", "Toàn",
    "Tài", "Tuấn", "Vũ", "Dũng", "Hậu", "Nghĩa", "Thiện", "Trung", "Đức", "Châu",
    "Đăng", "Hà", "Hoàng", "Quang", "Phúc", "Huy", "Thịnh", "Thanh", "Tân", "Bình",
    "Anh", "Kiên", "Nhật", "Văn", "Tiến", "Việt", "Thái", "Cường", "Tường", "Lộc",
    "Lan", "Mai", "Hương", "Hoa", "Ngọc", "Hạnh", "Huyền", "Thảo", "Yến", "Phương",
    "Tâm", "Trâm", "Vy", "Giang", "My", "Diệu", "Nhung", "Trinh", "Bích", "Trang",
    "Duyên", "Linh", "Thúy", "Tuyết", "Loan", "Thắm", "Hồng", "Kim", "Quyên", "Nga",
    "Lệ", "Thu", "Liên", "Dạ", "Khánh Linh", "Bảo Trân", "Minh Thư", "Thanh Tú", "Ngọc Anh", "Thùy Chi",
    "Cẩm Tú", "Hà My", "Hoài An", "Mai Phương", "Hồng Nhung", "Quỳnh Chi", "Thiên Kim", "Nhật Hạ", "Bích Ngọc", "Ngọc Trâm"]
    return random.choice(first_names) + " " + random.choice(last_names)

def generate_description(min_length=50):
    words = ["sản phẩm", "chất lượng", "tuyệt vời", "mua lần thứ", "dịch vụ", "giao hàng", "nhanh chóng", "bền đẹp", "thời trang", "hợp xu hướng", "mẫu mã đẹp", "giá cả hợp lý",
             "tư vấn tận tình", "nhiều mẫu mã", "mua nhiều lần", "khách hàng thân thiết", "hàng chính hãng", "rất đáng tiền", "đóng gói cẩn thận", "phù hợp mọi lứa tuổi", "sang trọng",
             "tinh tế", "cảm giác tuyệt vời", "sẽ mua tiếp", "giao hàng nhanh", "sản phẩm như mô tả", "bảo hành tốt", "cảm giác thoải mái", "độ bền cao", "chống nước tốt", "dễ dàng sử dụng",
             "màu sắc đẹp", "rất vừa vặn", "phù hợp xu hướng", "đổi trả dễ dàng", "chất liệu cao cấp", "cảm giác êm ái", "tính năng vượt trội", "mua tặng bạn bè", "hỗ trợ tận tình", "phục vụ chu đáo",
             "mang phong cách riêng", "giá cả ổn định", "hàng nhập khẩu", "rất ấn tượng", "chống trầy xước", "hài lòng tuyệt đối", "sản phẩm độc quyền", "rất đáng sở hữu", "chất vải thoáng mát",
             "công nghệ tiên tiến", "cảm giác đẳng cấp", "bảo hành 12 tháng", "độ hoàn thiện cao", "thương hiệu nổi tiếng", "rất đẹp", "rất hài lòng", "thiết kế thông minh", "hàng chuẩn", "rất đáng giá", "hoàn toàn yên tâm"]
    return " ".join(random.choices(words, k=min_length))

def generate_search_history():
    search_terms = ["áo khoác nam", "giày thể thao", "váy dạ hội", "túi xách nữ", "quần jean nam", "đồng hồ thời trang", "mắt kính chống tia UV", "nước hoa nam", "nước hoa nữ", "áo sơ mi công sở",
                    "giày cao gót", "dép sandal nữ", "túi đeo chéo", "mũ lưỡi trai nam", "mũ rộng vành nữ", "balo laptop", "vali du lịch", "đồ lót nữ", "áo hoodie nam", "quần legging nữ", "đầm dạo phố",
                    "đầm công sở", "khăn choàng cổ", "găng tay da", "thắt lưng da nam", "ví da nữ", "giày chạy bộ", "giày lười nam", "kính râm nữ", "áo thể thao nam", "quần short nữ", "bộ đồ ngủ nữ",
                    "bộ vest nam", "váy maxi", "quần jogger nam", "đồng hồ thông minh", "áo phao nữ", "áo polo nam", "giày tây nam", "áo gió nữ", "tất vớ thời trang", "áo len nam", "áo dạ nữ", "đồ đôi tình nhân",
                    "mũ len nam", "găng tay len nữ", "bộ đồ gym nam", "áo ba lỗ nữ", "đầm maxi đi biển", "bộ pijama nữ", "quần kaki nam", "áo dài truyền thống", "quần culottes nữ", "bộ vest nữ", "balo thời trang nữ",
                    "áo phông nam", "quần tất nữ", "áo dài cách tân", "quần yếm nữ", "khăn lụa nữ"]
    return ", ".join(random.choices(search_terms, k=3))

job_name_ = [
    "Bác sĩ", "Y tá", "Dược sĩ", "Kỹ thuật viên y tế", "Nhà tâm lý học", "Bác sĩ phẫu thuật", 
    "Nha sĩ", "Chuyên gia dinh dưỡng", "Nhân viên y tế cộng đồng", "Bác sĩ thú y", 
    "Lập trình viên", "Kỹ sư phần mềm", "Quản trị hệ thống", "Chuyên gia AI", "Chuyên viên bảo mật", 
    "Nhà khoa học dữ liệu", "Kỹ sư DevOps", "Chuyên viên phân tích dữ liệu", "Nhà phát triển game", "Quản trị mạng", 
    "Nhà đầu tư", "Chuyên gia tài chính", "Kế toán", "Kiểm toán viên", "Nhân viên ngân hàng", 
    "Nhân viên bảo hiểm", "Chuyên viên tư vấn tài chính", "Nhà phân tích kinh tế", "Chuyên gia blockchain", "Nhà đầu tư chứng khoán", 
    "Giáo viên", "Giảng viên đại học", "Nhà nghiên cứu", "Gia sư", "Chuyên viên đào tạo", 
    "Biên tập viên", "Nhà văn", "Nhà báo", "Dịch giả", "Nhà thơ", 
    "Luật sư", "Công chứng viên", "Công tố viên", "Thẩm phán", "Cố vấn pháp lý", 
    "Kiến trúc sư", "Kỹ sư xây dựng", "Nhà thiết kế nội thất", "Kỹ sư cầu đường", "Chuyên viên quy hoạch đô thị", 
    "Diễn viên", "Ca sĩ", "Nhạc sĩ", "Nghệ sĩ piano", "Đạo diễn", 
    "Nhiếp ảnh gia", "Họa sĩ", "Nhà thiết kế đồ họa", "Chuyên viên truyền thông", "Người mẫu", 
    "Phi công", "Tiếp viên hàng không", "Kiểm soát viên không lưu", "Thợ máy hàng không", "Chuyên gia logistics", 
    "Bộ đội", "Công an", "Nhân viên cứu hỏa", "Nhân viên cứu hộ", "Chuyên gia an ninh", 
    "Đầu bếp", "Nhà phê bình ẩm thực", "Nhân viên phục vụ", "Chuyên gia dinh dưỡng", "Thợ làm bánh", 
    "Chuyên viên marketing", "Chuyên viên SEO", "Nhân viên bán hàng", "Chuyên gia thương mại điện tử", "Quản lý nhãn hàng", 
    "Công nhân", "Thợ điện", "Thợ mộc", "Thợ hàn", "Kỹ thuật viên cơ khí", 
    "Kỹ thuật viên ô tô", "Thợ sửa chữa điện thoại", "Kỹ thuật viên điện lạnh", "Kỹ thuật viên âm thanh", "Kỹ thuật viên ánh sáng", 
    "Nông dân", "Kỹ sư nông nghiệp", "Nhà nghiên cứu thực phẩm", "Kỹ thuật viên nuôi trồng thủy sản", "Nhà nghiên cứu sinh học", 
    "Nhà thiên văn học", "Nhà vật lý học", "Nhà hóa học", "Nhà toán học", "Nhà nghiên cứu môi trường", 
    "Chuyên viên quản lý dự án", "Nhà tư vấn doanh nghiệp", "Giám đốc điều hành", "Quản lý nhân sự", "Chuyên gia phát triển kinh doanh", 
    "Thợ cắt tóc", "Chuyên viên làm đẹp", "Chuyên viên spa", "Chuyên viên trang điểm", "Thợ xăm", 
    "Huấn luyện viên thể hình", "Trọng tài thể thao", "Bình luận viên thể thao", "Vận động viên chuyên nghiệp", "Chuyên viên vật lý trị liệu", 
    "Nhân viên thư viện", "Nhà sử học", "Nhà khảo cổ học", "Nhà triết học", "Nhà ngôn ngữ học", 
    "Kỹ sư năng lượng", "Chuyên gia môi trường", "Nhà nghiên cứu khí hậu", "Chuyên viên năng lượng tái tạo", "Kỹ sư điện", 
    "Chuyên viên tư vấn tâm lý", "Nhà trị liệu ngôn ngữ", "Nhân viên xã hội", "Cố vấn giáo dục", "Chuyên gia hướng nghiệp", 
    "Nhà ngoại giao", "Nhân viên đại sứ quán", "Chuyên gia quan hệ quốc tế", "Phóng viên quốc tế", "Nhà hoạt động xã hội", 
    "Chuyên gia kiểm thử phần mềm", "Nhà phát triển ứng dụng di động", "Nhà thiết kế UX/UI", "Chuyên viên an ninh mạng", "Kỹ sư robotics", 
    "Nhà phát triển Web", "Kỹ sư phần mềm nhúng", "Chuyên viên RPA", "Kỹ sư AI", "Kỹ sư dữ liệu", 
    "Chuyên gia phát triển bền vững", "Nhà phân tích hệ thống", "Kỹ sư tự động hóa", "Nhà nghiên cứu trí tuệ nhân tạo", "Chuyên gia học máy", 
    "Chuyên viên phân tích rủi ro", "Nhà phân tích thị trường", "Nhà đầu tư bất động sản", "Chuyên gia quản lý tài sản", "Nhà môi giới chứng khoán", 
    "Kỹ sư y sinh", "Nhà nghiên cứu dược phẩm", "Nhà khoa học thần kinh", "Chuyên viên phục hồi chức năng", "Nhà nghiên cứu tế bào gốc", 
    "Nhà sản xuất phim", "Chuyên gia hoạt hình", "Biên tập viên phim", "Nhà viết kịch bản", "Nhà sản xuất âm nhạc", 
    "Chuyên viên phát triển nội dung", "Nhà sản xuất chương trình truyền hình", "Nhà tổ chức sự kiện", "Chuyên gia truyền thông số", "Chuyên gia quảng cáo", 
    "Nhà sáng tạo nội dung", "Nhà phê bình nghệ thuật", "Chuyên gia thương hiệu", "Nhà phân tích hành vi người tiêu dùng", "Nhà tư vấn sáng tạo", 
    "Nhà khoa học máy tính", "Nhà nghiên cứu bảo mật", "Chuyên gia AI Ethics", "Nhà nghiên cứu nhận dạng giọng nói", "Chuyên gia thực tế ảo", 
    "Nhà phân tích dữ liệu lớn", "Kỹ sư học sâu", "Chuyên viên quản lý chất lượng", "Chuyên viên kiểm thử tự động", "Kỹ sư tích hợp hệ thống"
]
# Nghề có xác suất mua hàng cao
nghe_mua_cao = [
    "Bác sĩ", "Luật sư", "Giám đốc điều hành", "Nhà đầu tư", "Nhà khoa học dữ liệu",
    "Kỹ sư phần mềm", "Chuyên gia AI", "Chuyên gia tài chính", "Kiến trúc sư", "Nhà sản xuất phim"
]

# Nghề có xác suất mua hàng trung bình
nghe_mua_trung_binh = [
    "Giáo viên", "Giảng viên đại học", "Nhà báo", "Chuyên viên marketing", "Chuyên viên nhân sự",
    "Nhà nghiên cứu", "Nhà thiết kế đồ họa", "Quản trị mạng", "Chuyên viên tư vấn tài chính", "Bác sĩ thú y"
]

# Nghề có xác suất mua hàng thấp
nghe_mua_thap = [
    "Nông dân", "Thợ điện", "Thợ hàn", "Thợ mộc", "Công nhân",
    "Nhân viên phục vụ", "Bảo vệ", "Nhân viên thư viện", "Nhân viên giao hàng", "Nhân viên bán vé"
]
spring = [
    "Áo sơ mi nam", "Áo sơ mi nữ", "Quần jean nam", "Quần jean nữ",
    "Áo thun nam", "Áo thun nữ", "Giày thể thao nam", "Giày thể thao nữ",
    "Túi xách nữ", "Balo nam", "Balo nữ", "Đồng hồ nam", "Đồng hồ nữ",
    "Váy công sở", "Áo gió nam", "Áo gió nữ", "Thắt lưng nam", "Thắt lưng nữ",
    "Khăn lụa nữ", "Mũ lưỡi trai nam"
]
summer = [
    "Áo thun nam", "Áo thun nữ", "Quần short nam", "Quần short nữ",
    "Giày lười nam", "Dép sandal nữ", "Mắt kính thời trang",
    "Váy maxi", "Áo dài cách tân", "Quần yếm nữ", "Mũ rộng vành nữ",
    "Bộ đồ ngủ nữ", "Bộ pijama nam", "Bộ pijama nữ"
]
autumn = [
    "Áo khoác nam", "Áo khoác nữ", "Áo hoodie nam", "Áo hoodie nữ",
    "Quần jogger nam", "Quần jogger nữ", "Bộ vest nam", "Bộ vest nữ",
    "Giày thể thao nam", "Giày thể thao nữ", "Thắt lưng nam", "Thắt lưng nữ",
    "Tất nam", "Tất nữ", "Khăn choàng cổ"
]
winter = [
    "Áo gió nam", "Áo gió nữ", "Áo len nam", "Áo len nữ", "Găng tay da",
    "Găng tay len", "Khăn choàng cổ", "Bộ vest nam", "Bộ vest nữ",
    "Tất nam", "Tất nữ", "Áo dài truyền thống", "Balo nam", "Balo nữ"
]

# Nhóm < 30 tuổi
under_30 = ["Casual", "Streetwear", "Thể thao", "Vintage", "Bohemian"]

for i in range(3):
    with open(f"synthetic_data_{i}.txt", "w", encoding="utf-8") as f:
        for _ in range(num_samples):
            age = random.randint(18, 60)
            avg_spent = round(random.uniform(0, 500), 2)
            clicks = random.randint(0, 100)
            purchases = random.randint(0, 30)
            distance_last_buy = random.randint(1, 60)
            rating = round(random.uniform(1, 10), 1)
            discount = random.randint(0, 1)
            product_views = random.randint(10, 1000)
            product_price = round(random.uniform(50, 500), 2)
            job = random.choice(job_name_)
            last_buy_product = random.choice(["Áo sơ mi nam", "Áo sơ mi nữ", "Quần jean nam", "Quần jean nữ", "Áo thun nam", "Áo thun nữ", "Áo khoác nam",
                                              "Áo khoác nữ", "Giày thể thao nam", "Giày thể thao nữ", "Giày cao gót", "Túi xách nữ", "Balo nam", "Balo nữ",
                                              "Mắt kính thời trang", "Đồng hồ nam", "Đồng hồ nữ", "Quần jogger nam", "Quần jogger nữ", "Đầm dạ hội", "Váy công sở",
                                              "Quần legging nữ", "Áo hoodie nam", "Áo hoodie nữ", "Áo gió nam", "Áo gió nữ", "Tất nam", "Tất nữ", "Thắt lưng nam",
                                              "Thắt lưng nữ", "Khăn choàng cổ", "Găng tay da", "Quần short nam", "Quần short nữ", "Bộ đồ ngủ nữ", "Bộ pijama nam",
                                              "Bộ pijama nữ", "Bộ vest nam", "Bộ vest nữ", "Váy maxi", "Giày lười nam", "Dép sandal nữ", "Áo dài truyền thống", "Áo dài cách tân",
                                              "Quần yếm nữ", "Khăn lụa nữ", "Mũ lưỡi trai nam", "Mũ rộng vành nữ", "Găng tay len", "Áo len nam", "Áo len nữ"])
            name_product = random.choice(["Áo sơ mi nam", "Áo sơ mi nữ", "Quần jean nam", "Quần jean nữ", "Áo thun nam", "Áo thun nữ", "Áo khoác nam", "Áo khoác nữ",
                                          "Giày thể thao nam", "Giày thể thao nữ", "Giày cao gót", "Túi xách nữ", "Balo nam", "Balo nữ", "Mắt kính thời trang", "Đồng hồ nam",
                                          "Đồng hồ nữ", "Quần jogger nam", "Quần jogger nữ", "Đầm dạ hội", "Váy công sở", "Quần legging nữ", "Áo hoodie nam", "Áo hoodie nữ",
                                          "Áo gió nam", "Áo gió nữ", "Tất nam", "Tất nữ", "Thắt lưng nam", "Thắt lưng nữ", "Khăn choàng cổ", "Găng tay da", "Quần short nam",
                                          "Quần short nữ", "Bộ đồ ngủ nữ", "Bộ pijama nam", "Bộ pijama nữ", "Bộ vest nam", "Bộ vest nữ", "Váy maxi", "Giày lười nam", "Dép sandal nữ",
                                          "Áo dài truyền thống", "Áo dài cách tân", "Quần yếm nữ", "Khăn lụa nữ", "Mũ lưỡi trai nam", "Mũ rộng vành nữ", "Găng tay len", "Áo len nam", "Áo len nữ"])
            type_ = get_category_by_product(name_product)
            seasion = random.choice(["Mùa xuân", "Mùa hạ", "Mùa thu", "Mùa đông"])
            color = random.choice(["Đỏ", "Xanh dương", "Xanh lá", "Vàng", "Cam", "Tím", "Hồng", "Nâu", "Đen", "Trắng", "Xám", "Bạc", "Vàng đồng", "Xanh ngọc", "Xanh rêu", "Xanh navy", "Xanh pastel",
                                   "Hồng pastel", "Cam đất", "Tím than", "Xanh biển", "Đỏ đô", "Đỏ cam", "Đỏ hồng", "Đỏ tía", "Xanh lá cây", "Xanh lá mạ", "Xanh cốm", "Xanh da trời", "Xanh lam", "Xanh nước biển",
                                   "Xanh coban", "Xanh đậm", "Xanh lục", "Xanh lá non", "Xanh chàm", "Xanh tím than", "Hồng cánh sen", "Hồng đào", "Hồng phấn", "Hồng nhạt", "Hồng đậm", "Hồng tím", "Hồng sen",
                                   "Hồng cam", "Hồng nude", "Cam sáng", "Cam tối", "Cam vàng", "Cam neon", "Cam hồng", "Tím khói", "Tím pastel", "Tím hồng", "Tím xanh", "Tím đỏ", "Tím cà", "Tím sẫm", "Tím nhạt",
                                   "Tím lợt", "Tím thẫm", "Tím lam", "Nâu sẫm", "Nâu hạt dẻ", "Nâu đất", "Nâu cà phê", "Nâu nhạt", "Nâu đỏ", "Nâu vàng", "Nâu cam", "Nâu khói", "Nâu trầm", "Đen tuyền", "Đen nhám",
                                   "Đen bóng", "Đen xám", "Xám ghi", "Xám tro", "Xám bạc", "Xám đá", "Xám xanh", "Xám khói", "Xám pastel", "Xám vàng", "Trắng sữa", "Trắng kem", "Trắng tinh", "Trắng hồng", "Trắng ngà",
                                   "Trắng xanh", "Trắng bạc", "Trắng xám", "Vàng chanh", "Vàng nghệ", "Vàng nhạt", "Vàng đất", "Vàng cam", "Vàng cát", "Vàng kem", "Vàng pastel", "Vàng neon", "Vàng đồng", "Vàng chói",
                                   "Bạc ánh kim", "Bạc trắng", "Bạc xám", "Bạc xanh", "Bạc tím"])
            brand = get_brand_by_product(name_product)
            style  = get_fashion_style_by_product(name_product)
            size = get_fashion_size_by_product(name_product)
            month_user = str(random.randint(1, 12))
            sex = str(random.randint(0,1))
            month_buy_product = str(random.randint(0,12))
            total_buy_product = str(random.randint(1, 50))
            cancel = str(random.randint(1, 10))
            return_ = str(random.randint(1, 10))
            not_buy = str(random.randint(1, 20))
            
            birth_month_bonus = 0.1 if month_buy_product in [month_user, (int(month_user) % 12) + 1] else 0
    
            product_popularity = {
               "Áo sơ mi nam": 0.65, "Áo sơ mi nữ": 0.63, "Quần jean nam": 0.78, "Quần jean nữ": 0.75, 
                "Áo thun nam": 0.85, "Áo thun nữ": 0.82, "Áo khoác nam": 0.60, "Áo khoác nữ": 0.58, 
                "Giày thể thao nam": 0.80, "Giày thể thao nữ": 0.77, "Giày cao gót": 0.72, "Túi xách nữ": 0.70, 
                "Balo nam": 0.68, "Balo nữ": 0.66, "Mắt kính thời trang": 0.55, "Đồng hồ nam": 0.50, 
                "Đồng hồ nữ": 0.48, "Quần jogger nam": 0.73, "Quần jogger nữ": 0.71, "Đầm dạ hội": 0.40, 
                "Váy công sở": 0.60, "Quần legging nữ": 0.58, "Áo hoodie nam": 0.62, "Áo hoodie nữ": 0.61, 
                "Áo gió nam": 0.50, "Áo gió nữ": 0.48, "Tất nam": 0.42, "Tất nữ": 0.40, 
                "Thắt lưng nam": 0.45, "Thắt lưng nữ": 0.43, "Khăn choàng cổ": 0.38, "Găng tay da": 0.36, 
                "Quần short nam": 0.70, "Quần short nữ": 0.68, "Bộ đồ ngủ nữ": 0.55, "Bộ pijama nam": 0.50, 
                "Bộ pijama nữ": 0.52, "Bộ vest nam": 0.30, "Bộ vest nữ": 0.28, "Váy maxi": 0.45, 
                "Giày lười nam": 0.60, "Dép sandal nữ": 0.58, "Áo dài truyền thống": 0.35, "Áo dài cách tân": 0.37, 
                "Quần yếm nữ": 0.42, "Khăn lụa nữ": 0.39, "Mũ lưỡi trai nam": 0.50, "Mũ rộng vành nữ": 0.48, 
                "Găng tay len": 0.30, "Áo len nam": 0.33, "Áo len nữ": 0.32
            }
            # Quy luật ẩn: Người mua có click cao, rating cao, giảm giá, khoảng cách mua gần
            buy_prob = (
                (clicks * 0.02 if clicks > 20 else clicks * -0.02) +
                (rating * 0.1 if rating > 8 else rating/5 * -0.05) +
                discount * 0.1 +
                (30 - distance_last_buy) * 0.02 +
                (avg_spent / 500) * 0.2 +
                (int(total_buy_product) / 50) * 0.2 +
                (product_views / 1000) * 0.1 +
                (1 if job in nghe_mua_cao else 0) * 0.1 +
                (0.5 if job in nghe_mua_trung_binh else 0) * 0.1 +
                (-1 if job in nghe_mua_thap else 0) * 0.1 +
                (1 if product_price > 200 and discount == 1 else -0.5) * 0.15 +
                (1 if purchases > 10 and discount == 1 else -1) * 0.15 +
                (1 if int(cancel)<=5 else -1) * 0.1 +
                (1 if int(return_)<=5 else -1) * 0.1 +
                (1 if int(not_buy)<=5 else -1) * 0.1 +
                (1 if age < 30 and style in under_30 else -1) * 0.15 + 
                (1 if seasion == "Mùa xuân" and name_product in spring else -1) * 0.1 +
                (1 if seasion == "Mùa hạ" and name_product in summer else -1) * 0.1 +
                (1 if seasion == "Mùa thu" and name_product in autumn else -1) * 0.1 +
                (1 if seasion == "Mùa đông" and name_product in winter else -1) * 0.1 +
                
                (1 if int(sex) == 0 and name_product in ["Áo sơ mi nam", "Quần jean nam", "Áo thun nam", "Áo khoác nam",
                                        "Giày thể thao nam", "Balo nam", "Đồng hồ nam", "Quần jogger nam",
                                        "Áo hoodie nam", "Áo gió nam", "Tất nam", "Thắt lưng nam",
                                        "Quần short nam", "Bộ pijama nam", "Bộ vest nam", "Giày lười nam",
                                        "Mũ lưỡi trai nam", "Áo len nam"] else -1) * 0.1 +
                (1 if get_category_by_product(last_buy_product) == type_ else -1) * 0.1 +
                
                birth_month_bonus + 
                product_popularity.get(name_product, 0)
            ) / 3.14
    
            buy_prob = min(max(buy_prob, 0), 1)
            label = 1 if buy_prob > 0.5 else 0
    
            data = [
                generate_name(),
                str(age),
                month_user,
                job,
                sex,
                str(avg_spent),
                str(clicks),
                generate_search_history(),
                str(purchases),
                month_buy_product,
                total_buy_product,
                last_buy_product,            
                str(distance_last_buy),
                cancel,
                return_,
                not_buy,
                str(rating),
                generate_description(20),
                str(discount),
                name_product,
                type_,
                seasion,
                color,
                brand,
                style,
                size,
                str(product_views),
                str(product_price),
                generate_description(50),
                str(label)
            ]
            f.write("_".join(data) + "\n")
    
    print("Synthetic dataset with hidden rules generated successfully!")
# Out:
# Synthetic dataset with hidden rules generated successfully!
# Synthetic dataset with hidden rules generated successfully!
# Synthetic dataset with hidden rules generated successfully!

# %%
import tensorflow as tf
from tensorflow.keras.layers import MultiHeadAttention,Embedding,Dense,Activation,Flatten,Input,BatchNormalization,Dropout,GlobalAveragePooling1D,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from pyvi import ViTokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import sys
import pandas as pd
# Out:
# 2025-03-06 22:38:45.496566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-06 22:38:45.570198: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-06 22:38:45.591643: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-06 22:38:45.729750: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# load data
"""
    Đọc file txt 
"""
data_collum_ = np.loadtxt("name_collum.txt", dtype=str, delimiter=",", encoding="utf-8")
print("Name collum")
for i in range(len(data_collum_)):
    print(f"-{i}, {data_collum_[i]}")
    
df = pd.read_csv("synthetic_data.txt", delimiter="_", header=None)
# df = df.drop(df.columns[0], axis=1)
print(df.head(1))
# Out:
# Name collum
# -0, Tên người dùng
# -1,  tuổi
# -2,  tháng sinh
# -3,  nghề nghiệp
# -4,  giới tính
# -5,  trung bình số tiền mỗi lần mua hàng 30 ngày gần nhất
# -6,  số lần click vào sản phẩm này trong 30 ngày gần nhất
# -7, 10 lịch sử tìm kiếm gần nhất
# -8,  số lần mua sản phẩm này
# -9,  tháng mua sản phẩm này
# -10,  tổng số lượng sản phẩm mà người dùng mua trong 30 ngày gần nhất
# -11,  tên sản phẩm vừa mua
# -12,  khoản cách mua sản phẩm này gần nhất
# -13,  số lần hủy sản phẩm này
# -14,  số lần trả sản phẩm này
# -15,  số lần thêm vào giỏ nhưng lại xóa của sản phẩm này
# -16,  điểm của sản phẩm
# -17, 10 bình luận về sản phẩm
# -18,  giảm giá
# -19,  tên sản phẩm
# -20,  loại sản phẩm
# -21,  mùa phát hành sản phẩm
# -22,  màu sắc sản phẩm
# -23,  thương hiệu sản phẩm
# -24,  phong cách sản phẩm
# -25,  size sản phẩm
# -26,  lượt bán của sản phẩm trong 30 ngày gần nhất
# -27,  giá tiền sản phẩm
# -28,  mô tả sản phẩm
# -29,  nhãn.
# ...

# %%
print(df.iloc[0, 0])
# Out:
# Mai Thúy

# %%
thu_vien_data_ = np.concatenate((df.iloc[:,0],df.iloc[:,17],df.iloc[:,28],df.iloc[:,7],df.iloc[:,19]))
thu_vien_data_ = thu_vien_data_.reshape(-1,)
data_vie_ = []
index_ = 0
tokenized_data = [ViTokenizer.tokenize(text) for text in thu_vien_data_]
tokenize_ = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n', split=" ")
tokenize_.fit_on_texts(tokenized_data)

# %%
print("Từ điển tokenized:", tokenize_.word_index)
# Out:
# Từ điển tokenized: {'rất': 1, 'hàng': 2, 'mua': 3, 'cảm_giác': 4, 'đẹp': 5, 'sản_phẩm': 6, 'tốt': 7, 'bảo_hành': 8, 'đáng': 9, 'lần': 10, 'xu_hướng': 11, 'tuyệt_vời': 12, 'chống': 13, 'nhiều': 14, 'hài_lòng': 15, 'bền': 16, 'tận_tình': 17, 'mẫu_mã': 18, 'giao': 19, 'dễ_dàng': 20, 'phù_hợp': 21, 'cao': 22, 'giá_cả': 23, 'độ': 24, 'nữ': 25, 'tặng': 26, 'bạn_bè': 27, 'chính': 28, 'hãng': 29, 'chu_đáo': 30, 'phục_vụ': 31, 'thời_trang': 32, 'đáng_giá': 33, 'sở_hữu': 34, 'như': 35, 'mô_tả': 36, 'êm_ái': 37, 'sang_trọng': 38, 'hợp': 39, 'thông_minh': 40, 'thoải_mái': 41, 'nước': 42, 'hỗ_trợ': 43, 'chất_lượng': 44, 'hoàn_thiện': 45, 'mang': 46, 'phong_cách': 47, 'dịch_vụ': 48, 'riêng': 49, '12': 50, 'tháng': 51, 'thiết_kế': 52, 'tiền': 53, 'nhập_khẩu': 54, 'công_nghệ': 55, 'tư_vấn': 56, 'tuyệt_đối': 57, 'hợp_lý': 58, 'màu_sắc_đẹp': 59, 'đóng_gói': 60, 'cẩn_thận': 61, 'tiên_tiến': 62, 'đổi': 63, 'trả': 64, 'vải': 65, 'thoáng': 66, 'thứ': 67, 'sẽ': 68, 'tiếp': 69, 'mát': 70, 'độc_quyền': 71, '
# ...

# %%
print(0/8)
# Out:
# 0.0

# %%
print((set([1,2,3,4,5]) & set([1,10,11,12]))==set())
# Out:
# False

# %%
print(random.randint(0, 1))
# Out:
# 0
